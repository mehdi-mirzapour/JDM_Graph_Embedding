# %%
import requests
import bs4
import re
import mysql.connector
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import networkx as nx
# %matplotlib inline 


config = {
'user': 'mirzapour',
'password': 'mehdim',
'host': 'karadoc.lirmm.fr',
'database': '05012019_rezojdm',
'raise_on_warnings': True
 }

jdm_db = mysql.connector.connect(**config)

jdm_cursor = jdm_db.cursor()

jdm_cursor.execute("SELECT * FROM nodes WHERE (type=1 or type=2) and weight>60 order by weight desc")
df_JDM_nodes=pd.DataFrame(jdm_cursor.fetchall(),columns=['ID','Name','Type','Weight'])

jdm_cursor.execute("SELECT * FROM edges where weight>50 and type=1 order by weight desc")
df_JDM_r_raff_sem=pd.DataFrame(jdm_cursor.fetchall(),columns=['ID','Source','Destination','Type','Weight'])

jdm_cursor.execute("SELECT * FROM edges where weight>50 and type=5 order by weight desc")
df_JDM_r_syn=pd.DataFrame(jdm_cursor.fetchall(),columns=['ID','Source','Destination','Type','Weight'])

jdm_cursor.execute("SELECT * FROM edges where weight>50 and type=6 order by weight desc")
df_JDM_r_isa=pd.DataFrame(jdm_cursor.fetchall(),columns=['ID','Source','Destination','Type','Weight'])

jdm_cursor.execute("SELECT * FROM edges where weight>50 and type=8 order by weight desc")
df_JDM_r_hypo=pd.DataFrame(jdm_cursor.fetchall(),columns=['ID','Source','Destination','Type','Weight'])

jdm_cursor.execute("SELECT * FROM edges where weight>50 and type=15 order by weight desc")
df_JDM_r_lieu=pd.DataFrame(jdm_cursor.fetchall(),columns=['ID','Source','Destination','Type','Weight'])

jdm_cursor.execute("SELECT * FROM edges where weight>50 and type=24 order by weight desc")
df_JDM_r_agent_1=pd.DataFrame(jdm_cursor.fetchall(),columns=['ID','Source','Destination','Type','Weight'])

jdm_cursor.execute("SELECT * FROM edges where weight>50 and type=26 order by weight desc")
df_JDM_r_agent=pd.DataFrame(jdm_cursor.fetchall(),columns=['ID','Source','Destination','Type','Weight'])



x1=set(df_JDM_r_raff_sem["Source"].unique())
x2=set(df_JDM_r_raff_sem["Destination"].unique())
y1=x1.union(x2)

x1=set(df_JDM_r_syn["Source"].unique())
x2=set(df_JDM_r_syn["Destination"].unique())
y2=x1.union(x2)


x1=set(df_JDM_r_isa["Source"].unique())
x2=set(df_JDM_r_isa["Destination"].unique())
y3=x1.union(x2)


x1=set(df_JDM_r_hypo["Source"].unique())
x2=set(df_JDM_r_hypo["Destination"].unique())
y4=x1.union(x2)


x1=set(df_JDM_r_lieu["Source"].unique())
x2=set(df_JDM_r_lieu["Destination"].unique())
y5=x1.union(x2)


x1=set(df_JDM_r_agent_1["Source"].unique())
x2=set(df_JDM_r_agent_1["Destination"].unique())
y6=x1.union(x2)


x1=set(df_JDM_r_agent["Source"].unique())
x2=set(df_JDM_r_agent["Destination"].unique())
y7=x1.union(x2)

y8=y1.union(y2,y3,y4,y5,y6,y7)

z=set(df_JDM_nodes["ID"].unique())

for id in range(df_JDM_nodes.shape[0]):
    graph_JDM.add_node(df_JDM_nodes.iloc[id]["Name"])
    
jdm_db.close()

seed_nodes=list(z.intersection(y8))
seed_nodes.sort()

# %%
import requests
import bs4
import re
import mysql.connector
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import networkx as nx
# %matplotlib inline 


graph_JDM= nx.Graph()

config = {
'user': 'mirzapour',
'password': 'mehdim',
'host': 'karadoc.lirmm.fr',
'database': '05012019_rezojdm',
'raise_on_warnings': True
 }

jdm_db = mysql.connector.connect(**config)

jdm_cursor = jdm_db.cursor()

jdm_db = mysql.connector.connect(**config)

jdm_cursor = jdm_db.cursor()

jdm_cursor.execute("SELECT * FROM nodes WHERE (type=1 or type=2) and weight>60 order by weight desc")
df_JDM_nodes=pd.DataFrame(jdm_cursor.fetchall(),columns=['ID','Name','Type','Weight'])
df_JDM_nodes.to_excel("df_JDM_nodes.xlsx")

jdm_cursor.execute("SELECT * FROM edges where weight>50 and type=1 order by weight desc")
df_JDM_r_raff_sem=pd.DataFrame(jdm_cursor.fetchall(),columns=['ID','Source','Destination','Type','Weight'])
df_JDM_r_raff_sem.to_excel("df_JDM_r_raff_sem.xlsx")

jdm_cursor.execute("SELECT * FROM edges where weight>50 and type=5 order by weight desc")
df_JDM_r_syn=pd.DataFrame(jdm_cursor.fetchall(),columns=['ID','Source','Destination','Type','Weight'])
df_JDM_r_syn.to_excel("df_JDM_r_syn.xlsx")

jdm_cursor.execute("SELECT * FROM edges where weight>50 and type=6 order by weight desc")
df_JDM_r_isa=pd.DataFrame(jdm_cursor.fetchall(),columns=['ID','Source','Destination','Type','Weight'])
df_JDM_r_isa.to_excel("df_JDM_r_isa.xlsx")

jdm_cursor.execute("SELECT * FROM edges where weight>50 and type=8 order by weight desc")
df_JDM_r_hypo=pd.DataFrame(jdm_cursor.fetchall(),columns=['ID','Source','Destination','Type','Weight'])
df_JDM_r_hypo.to_excel("df_JDM_r_hypo.xlsx")

jdm_cursor.execute("SELECT * FROM edges where weight>50 and type=15 order by weight desc")
df_JDM_r_lieu=pd.DataFrame(jdm_cursor.fetchall(),columns=['ID','Source','Destination','Type','Weight'])
df_JDM_r_lieu.to_excel("df_JDM_r_lieu.xlsx")

jdm_cursor.execute("SELECT * FROM edges where weight>50 and type=24 order by weight desc")
df_JDM_r_agent_1=pd.DataFrame(jdm_cursor.fetchall(),columns=['ID','Source','Destination','Type','Weight'])
df_JDM_r_agent_1.to_excel("df_JDM_r_agent_1.xlsx")

jdm_cursor.execute("SELECT * FROM edges where weight>50 and type=26 order by weight desc")
df_JDM_r_agent=pd.DataFrame(jdm_cursor.fetchall(),columns=['ID','Source','Destination','Type','Weight'])
df_JDM_r_agent.to_excel("df_JDM_r_agent.xlsx")

jdm_db.close()

# %%
import requests
import bs4
import re
import datetime
import mysql.connector
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import networkx as nx
# %matplotlib inline 


df_JDM_nodes=pd.read_excel("df_JDM_nodes.xlsx")
df_JDM_seed_words=pd.read_excel("List_of_Seed_Words_Top_30000.xlsx")
seedwords=list(df_JDM_seed_words["Nodes"])

df_JDM_r_raff_sem=pd.read_excel("df_JDM_r_raff_sem.xlsx")
df_JDM_r_syn=pd.read_excel("df_JDM_r_syn_84.xlsx")
df_JDM_r_isa=pd.read_excel("df_JDM_r_isa_230.xlsx")
df_JDM_r_hypo=pd.read_excel("df_JDM_r_hypo_120.xlsx")
df_JDM_r_lieu=pd.read_excel("df_JDM_r_lieu_60.xlsx")
df_JDM_r_agent_1=pd.read_excel("df_JDM_r_agent_1.xlsx")
df_JDM_r_agent=pd.read_excel("df_JDM_r_agent.xlsx")

# %%
from IPython.display import clear_output

def remove_non_related_rows_for_nodes(df_JDM_r_relation,seedwords):
    df_JDM_r_relation_=df_JDM_r_relation.copy()
    lenght=df_JDM_r_relation_.shape[0]
    for row in range(lenght):
        if (df_JDM_r_relation_.loc[row,"ID"] not in seedwords):
            df_JDM_r_relation_=df_JDM_r_relation_.drop(row,axis=0)
        print(row/lenght,"%")
        clear_output(wait=True)
    df_JDM_r_relation_=df_JDM_r_relation_.reset_index(drop=True)
    return(df_JDM_r_relation_)


def remove_non_related_rows_for_links(df_JDM_r_relation,seedwords):
    df_JDM_r_relation_=df_JDM_r_relation.copy()
    lenght=df_JDM_r_relation_.shape[0]
    for row in range(lenght):
        if (df_JDM_r_relation_.loc[row,"Source"] not in seedwords) or (df_JDM_r_relation_.loc[row,"Destination"] not in seedwords):
            df_JDM_r_relation_=df_JDM_r_relation_.drop(row,axis=0)
        print(row/lenght,"%")
        clear_output(wait=True)
    df_JDM_r_relation_=df_JDM_r_relation_.reset_index(drop=True)
    return(df_JDM_r_relation_)



# df_JDM_r_isa[df_JDM_r_isa["Weight"]>230].to_excel("df_JDM_r_isa_230.xlsx")
# df_JDM_r_hypo[df_JDM_r_hypo["Weight"]>120].to_excel("df_JDM_r_hypo_120.xlsx")
# df_JDM_r_syn[df_JDM_r_syn["Weight"]>84].to_excel("df_JDM_r_syn_84.xlsx")
# df_JDM_r_lieu[df_JDM_r_lieu["Weight"]>60].to_excel("df_JDM_r_lieu_60.xlsx")


df_JDM_nodes_removed=remove_non_related_rows_for_nodes(df_JDM_nodes,seedwords)
df_JDM_r_agent_removed=remove_non_related_rows_for_links(df_JDM_r_agent,seedwords)
df_JDM_r_agent_1_removed=remove_non_related_rows_for_links(df_JDM_r_agent_1,seedwords)
df_JDM_r_lieu_removed=remove_non_related_rows_for_links(df_JDM_r_lieu,seedwords)
df_JDM_r_hypo_removed=remove_non_related_rows_for_links(df_JDM_r_hypo,seedwords)
df_JDM_r_raff_sem_removed=remove_non_related_rows_for_links(df_JDM_r_raff_sem,seedwords)
df_JDM_r_syn_removed=remove_non_related_rows_for_links(df_JDM_r_syn,seedwords)
df_JDM_r_isa_removed=remove_non_related_rows_for_links(df_JDM_r_isa,seedwords)

# %%
df_JDM_nodes_removed.to_excel("./removed_excels/df_JDM_nodes_removed.xlsx")
df_JDM_r_agent_removed.to_excel("./removed_excels/df_JDM_r_agent_removed.xlsx")
df_JDM_r_agent_1_removed.to_excel("./removed_excels/df_JDM_r_agent_1_removed.xlsx")
df_JDM_r_lieu_removed.to_excel("./removed_excels/df_JDM_r_lieu_removed.xlsx")
df_JDM_r_hypo_removed.to_excel("./removed_excels/df_JDM_r_hypo_removed.xlsx")
df_JDM_r_raff_sem_removed.to_excel("./removed_excels/df_JDM_r_raff_sem_removed.xlsx")
df_JDM_r_syn_removed.to_excel("./removed_excels/df_JDM_r_syn_removed.xlsx")
df_JDM_r_isa_removed.to_excel("./removed_excels/df_JDM_r_isa_removed.xlsx")

# %%
df_JDM_all_links = pd.concat([df_JDM_r_agent_removed, df_JDM_r_agent_1_removed,
                          df_JDM_r_lieu_removed, df_JDM_r_hypo_removed,
                          df_JDM_r_raff_sem_removed,df_JDM_r_syn_removed,
                          df_JDM_r_isa_removed])
df_JDM_all_links=df_JDM_all_links.reset_index(drop=True)

df_JDM_all_links.to_excel("./removed_excels/df_JDM_all_links.xlsx")

# %%
df_JDM_all_links["Source_Name"]=""
df_JDM_all_links["Destination_Name"]=""
# df_JDM_nodes.set_index('ID',inplace=True)

for row in range(df_JDM_all_links.shape[0]):
        df_JDM_all_links.loc[row,"Source_Name"]=df_JDM_nodes.loc[df_JDM_all_links.loc[row,"Source"],"Name"]
        df_JDM_all_links.loc[row,"Destination_Name"]=df_JDM_nodes.loc[df_JDM_all_links.loc[row,"Destination"],"Name"]  

df_JDM_all_links.to_excel("./removed_excels/df_JDM_all_links.xlsx")

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import networkx as nx
# %matplotlib inline 

graph_JDM = nx.DiGraph()

graph_dic=[]
for row in range(len(df_JDM_all_links["ID"])):
    graph_dic.append((df_JDM_all_links["Source_Name"][row],df_JDM_all_links["Destination_Name"][row],df_JDM_all_links["Weight"][row]))
    
graph_JDM.add_weighted_edges_from(graph_dic)

nx.write_gexf(graph_JDM, "graph_JDM.gexf")

# %%
import pandas as pd
import numpy as np
import networkx as nx
import node2vec
from gensim.models import Word2Vec

'''
Pipeline for representational learning for all nodes in a graph.
'''

graph_JDM = nx.read_gexf("graph_JDM.gexf")
graph_JDM_words = node2vec.Graph(graph_JDM, True, 1, 1)
graph_JDM_words.preprocess_transition_probs()
walks = graph_JDM_words.simulate_walks(200, 80)
# Out:
# Walk iteration:
# 1 / 200
# 2 / 200
# 3 / 200
# 4 / 200
# 5 / 200
# 6 / 200
# 7 / 200
# 8 / 200
# 9 / 200
# 10 / 200
# 11 / 200
# 12 / 200
# 13 / 200
# 14 / 200
# 15 / 200
# 16 / 200
# 17 / 200
# 18 / 200
# 19 / 200
# 20 / 200
# 21 / 200
# 22 / 200
# 23 / 200
# 24 / 200
# 25 / 200
# 26 / 200
# 27 / 200
# 28 / 200
# 29 / 200
# 30 / 200
# 31 / 200
# 32 / 200
# 33 / 200
# 34 / 200
# 35 / 200
# 36 / 200
# 37 / 200
# 38 / 200
# 39 / 200
# 40 / 200
# 41 / 200
# 42 / 200
# 43 / 200
# 44 / 200
# 45 / 200
# 46 / 200
# 47 / 200
# 48 / 200
# 49 / 200
# 50 / 200
# 51 / 200
# 52 / 200
# 53 / 200
# 54 / 200
# 55 / 200
# 56 / 200
# 57 / 200
# 58 / 200
# 59 / 200
# 60 / 200
# 61 / 200
# 62 / 200
# 63 / 200
# 64 / 200
# 65 / 200
# 66 / 200
# 67 / 200
# 68 / 200
# 69 / 200
# 70 / 200
# 71 / 200
# 72 / 200
# 73 / 200
# 74 / 200
# 75 / 200
# 76 / 200
# 77 / 200
# 78 / 200
# 79 / 200
# 80 / 200
# 81 / 200
# 82 / 200
# 83 / 200
# 84 / 200
# 85 / 200
# 86 / 200
# 87 / 200
# 88 / 200
# 89 / 200
# 90 / 200
# 91 / 200
# 92 / 200
# 93 / 200
# 94 / 200
# 95 / 200
# 96 / 200
# 97 / 200
# 98 / 200
# 99 / 200
# 100 / 200
# 101 / 200
# 102 / 200
# 103 / 200
# 104 / 200
# 105 / 200
# 106 / 200
# 107 / 200
# 108 / 200
# 109 / 200
# 110 / 200
# 111 / 200
# 112 / 200
# 113 / 200
# 114 / 200
# 115 / 200
# 116 / 200
# 117 / 200
# 118 / 200
# 119 / 200
# 120 / 200
# 121 / 200
# 122 / 200
# 123 / 200
# 124 / 200
# 125 / 200
# 126 / 200
# 127 / 200
# 128 / 200
# 129 / 200
# 130 / 200
# 131 / 200
# 132 / 200
# 133 / 200
# 134 / 200
# 135 / 200
# 136 / 200
# 137 / 200
# 138 / 200
# 139 / 200
# 140 / 200
# 141 / 200
# 142 / 200
# 143 / 200
# 144 / 200
# 145 / 200
# 146 / 200
# 147 / 200
# 148 / 200
# 149 / 200
# 150 / 200
# 151 / 200
# 152 / 200
# 153 / 200
# 154 / 200
# 155 / 200
# 156 / 200
# 157 / 200
# 158 / 200
# 159 / 200
# 160 / 200
# 161 / 200
# 162 / 200
# 163 / 200
# 164 / 200
# 165 / 200
# 166 / 200
# 167 / 200
# 168 / 200
# 169 / 200
# 170 / 200
# 171 / 200
# 172 / 200
# 173 / 200
# 174 / 200
# 175 / 200
# 176 / 200
# 177 / 200
# 178 / 200
# 179 / 200
# 180 / 200
# 181 / 200
# 182 / 200
# 183 / 200
# 184 / 200
# 185 / 200
# 186 / 200
# 187 / 200
# 188 / 200
# 189 / 200
# 190 / 200
# 191 / 200
# 192 / 200
# 193 / 200
# 194 / 200
# 195 / 200
# 196 / 200
# 197 / 200
# 198 / 200
# 199 / 200
# 200 / 200

# %%
# walks = [list(map(str, walk)) for walk in walks]
model = Word2Vec(walks, size=20, window=10, min_count=0, sg=1, workers=8, iter=1)
model.save("word_embedding_JDM.emd")

# %%
import node2vec
from gensim.models import Word2Vec,KeyedVectors
from gensim.test.utils import datapath
import gensim
import pandas as pd

model = KeyedVectors.load('word_embedding_JDM.emd')

print(model.wv.__getitem__("rue"))
print(model.most_similar("rue"))
print(model.similarity('femme', 'homme'))
print(model.most_similar_cosmul(positive=['femme', 'roi'], negative=['homme']))
# Out:
# [ 0.7072633  -0.6196579  -0.2351085   0.2550599  -0.3730932   0.5003791
#  -0.16516608  0.06802143 -0.0112722   0.30567467 -1.3743273   0.85213673
#  -0.2186183  -1.2228203  -0.42450523  0.8457574  -1.0347408  -1.4323641
#   0.6002152   0.13123718]
# [('bourg', 0.9664750695228577), ('village', 0.9616600275039673), ('voie', 0.9584978818893433), ('rue>215052', 0.9531109929084778), ('hameau', 0.9515471458435059), ('commune', 0.9469115734100342), ('fraction', 0.9321660399436951), ('quartier', 0.9305980205535889), ('arrondissement', 0.9257712364196777), ('agglomération', 0.9192002415657043)]
# 0.9458277
# [('riche', 1.001927375793457), ('cossu', 1.0011340379714966), ('princesse', 0.9894653558731079), ('nanti', 0.9861059784889221), ('millionnaire', 0.9816352128982544), ('moyen âge', 0.9720843434333801), ('Louis XIII', 0.9714321494102478), ('prince charmant', 0.9690521359443665), ('conte>146367', 0.9666783213615417), ('Moyen Âge', 0.964341938495636)]
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:10: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   # Remove the CWD from sys.path while we load stuff.
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:11: DeprecationWarning: Call to deprecated `similarity` (Method will be removed in 4.0.0, use self.wv.similarity() instead).
#   # This is added back by InteractiveShellApp.init_path()
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:12: DeprecationWarning: Call to deprecated `most_similar_cosmul` (Method will be removed in 4.0.0, use self.wv.most_similar_cosmul() instead).
#   if sys.path[0] == '':

# %%
model.wv.__getitem__("rue").shape
# Out:
# (20,)

# %%
from IPython.display import clear_output

df_JDM_all_links=pd.read_excel("./removed_excels/df_JDM_all_links.xlsx")

length=df_JDM_all_links.shape[0]
for row in range(length):
    if ('>' in df_JDM_all_links.loc[row,"Source_Name"]) or ('>' in df_JDM_all_links.loc[row,"Destination_Name"]):
        df_JDM_all_links=df_JDM_all_links.drop(row,axis=0)
    print(row/length,"%")
    clear_output(wait=True)

df_JDM_all_links=df_JDM_all_links.reset_index(drop=True)

df_JDM_all_links["r_raff_sem"]=""
df_JDM_all_links["r_syn"]=""
df_JDM_all_links["r_isa"]=""
df_JDM_all_links["r_hypo"]=""
df_JDM_all_links["r_lieu"]=""
df_JDM_all_links["r_agent_1"]=""
df_JDM_all_links["r_agent"]=""
df_JDM_all_links.to_excel("raw_JDM_dataset.xlsx")

# %%
import node2vec
from gensim.models import Word2Vec,KeyedVectors
from gensim.test.utils import datapath
import gensim
import pandas as pd

df_JDM_all_relations=pd.read_excel("raw_JDM_dataset_Kevin.xlsx")
df_JDM_all_relations["#_of_relations"]=df_JDM_all_relations[["r_syn","r_isa","r_hypo","r_lieu","r_agent_1","r_agent"]].sum(axis=1)
df_JDM_all_relations=df_JDM_all_relations[df_JDM_all_relations["#_of_relations"]>1].reset_index(drop=True)
df_JDM_all_relations=df_JDM_all_relations.drop("#_of_relations",axis=1)


source_list=["source_feature_"+str(id) for id in range(20)]
destination_list=["destination_feature_"+str(id) for id in range(20)]
for id in range(20):
    df_JDM_all_relations.insert(id+4,source_list[id],"")
for id in range(20):
    df_JDM_all_relations.insert(id+24,destination_list[id],"")   

model = KeyedVectors.load('word_embedding_JDM.emd')
        
for row in range(df_JDM_all_relations.shape[0]):
    source_features=model.wv.__getitem__(df_JDM_all_relations["Source_Name"][row])
    destination_features=model.wv.__getitem__(df_JDM_all_relations["Destination_Name"][row])
    both_features=list(source_features)+list(destination_features)
    
    for feature_index in range(20):
        df_JDM_all_relations.iloc[row,feature_index+4]=both_features[feature_index]
        df_JDM_all_relations.iloc[row,feature_index+24]=both_features[feature_index+20]
        
df_JDM_all_relations.to_excel("cleaned_JDM_dataset.xlsx")

# %% [markdown]
# Train and the model and prediction

# %%
import pandas as pd
from sklearn.model_selection import train_test_split

df_JDM_dataset=pd.read_excel("cleaned_JDM_dataset.xlsx")
source_list=["source_feature_"+str(id) for id in range(20)]
destination_list=["destination_feature_"+str(id) for id in range(20)]

features=["r_syn","r_isa","r_hypo","r_lieu","r_agent_1","r_agent"]


rf_model_scores_test={}
recall={}
accuracy={}
precision={}
f1={}

for feature in features:
    
    X = df_JDM_dataset[source_list+destination_list]
    y = df_JDM_dataset[feature]
    
    X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.2,random_state=0)

    from sklearn.ensemble import RandomForestClassifier
    model = RandomForestClassifier(n_estimators=80, n_jobs=4, random_state=1)
    model.fit(X_train, y_train)
    y_pred=model.predict(X_test)
    
    import sklearn.metrics
    recall[feature]=sklearn.metrics.recall_score(y_test, y_pred)
    accuracy[feature]=sklearn.metrics.accuracy_score(y_test, y_pred)
    precision[feature]=sklearn.metrics.precision_score(y_test, y_pred)
    f1[feature]=sklearn.metrics.f1_score(y_test, y_pred)
    
    rf_model_scores_test[feature]=model.score(X_test, y_test)

    
print(recall)
print(precision)
print(f1)
print(accuracy)
# Out:
# /anaconda3/lib/python3.7/site-packages/sklearn/ensemble/weight_boosting.py:29: DeprecationWarning: numpy.core.umath_tests is an internal NumPy module and should not be imported. It will be removed in a future NumPy release.
#   from numpy.core.umath_tests import inner1d
# {'r_syn': 0.9889807162534435, 'r_isa': 0.6635514018691588, 'r_hypo': 0.6458333333333334, 'r_lieu': 0.5808823529411765, 'r_agent_1': 0.8181818181818182, 'r_agent': 0.75}
# {'r_syn': 0.8820638820638821, 'r_isa': 0.7282051282051282, 'r_hypo': 0.7126436781609196, 'r_lieu': 0.8061224489795918, 'r_agent_1': 1.0, 'r_agent': 1.0}
# {'r_syn': 0.9324675324675326, 'r_isa': 0.6943765281173593, 'r_hypo': 0.6775956284153006, 'r_lieu': 0.6752136752136753, 'r_agent_1': 0.9, 'r_agent': 0.8571428571428571}
# {'r_syn': 0.8793503480278422, 'r_isa': 0.7099767981438515, 'r_hypo': 0.7262180974477959, 'r_lieu': 0.8236658932714617, 'r_agent_1': 0.9953596287703016, 'r_agent': 0.9976798143851509}
# {'r_syn': 0.8793503480278422,
#  'r_isa': 0.7099767981438515,
#  'r_hypo': 0.7262180974477959,
#  'r_lieu': 0.8236658932714617,
#  'r_agent_1': 0.9953596287703016,
#  'r_agent': 0.9976798143851509}

# %%
# Model Metrics Calculated by Cross Validation 


import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score


df_JDM_dataset=pd.read_excel("cleaned_JDM_dataset.xlsx")
source_list=["source_feature_"+str(id) for id in range(20)]
destination_list=["destination_feature_"+str(id) for id in range(20)]

features=["r_syn","r_isa","r_hypo","r_lieu","r_agent_1","r_agent"]

recall={}
accuracy={}
precision={}
f1={}

for feature in features:
    
    X = df_JDM_dataset[source_list+destination_list]
    y = df_JDM_dataset[feature]
    
    from sklearn.ensemble import RandomForestClassifier
    model = RandomForestClassifier(n_estimators=70, n_jobs=4, random_state=1)
    precision[feature] = cross_val_score(model, X, y, cv=10, scoring='precision').mean()
    recall[feature] = cross_val_score(model, X, y, cv=10, scoring='recall').mean()
    f1[feature] = cross_val_score(model, X, y, cv=10, scoring='f1').mean()
    accuracy[feature] = cross_val_score(model, X, y, cv=10, scoring='accuracy').mean()

print(precision)
print(recall)
print(f1)
print(accuracy)
# Out:
# {'r_syn': 0.8480633159476616, 'r_isa': 0.9077584201754123, 'r_hypo': 0.8216920456778494, 'r_lieu': 0.8729237663181253, 'r_agent_1': 0.8473292275662615, 'r_agent': 0.7737843921311663}
# {'r_syn': 0.7905109489051095, 'r_isa': 0.5457497857754927, 'r_hypo': 0.3721128892733564, 'r_lieu': 0.8405213130504403, 'r_agent_1': 0.6157732964709709, 'r_agent': 0.205206548638873}
# {'r_syn': 0.8163099205321691, 'r_isa': 0.6609155645080852, 'r_hypo': 0.5062822133855118, 'r_lieu': 0.8539502898283244, 'r_agent_1': 0.7044748185950513, 'r_agent': 0.31395553865916087}
# {'r_syn': 0.8574158727131393, 'r_isa': 0.9450651025867698, 'r_hypo': 0.944685378424133, 'r_lieu': 0.9021633384507032, 'r_agent_1': 0.9398227922841667, 'r_agent': 0.9739839406287315}

# %%
# Model Hyper-Parameter Tuning Using GridSearch for Getting Optimized Value of n_estimators


import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import GridSearchCV


df_JDM_dataset=pd.read_excel("cleaned_JDM_dataset.xlsx")
source_list=["source_feature_"+str(id) for id in range(20)]
destination_list=["destination_feature_"+str(id) for id in range(20)]

features=["r_syn","r_isa","r_hypo","r_lieu","r_agent_1","r_agent"]

param_grid = dict(n_estimators=list(range(10, 180,20)))

accuracy={}

for feature in features:
    
    X = df_JDM_dataset[source_list+destination_list]
    y = df_JDM_dataset[feature]
    
    from sklearn.ensemble import RandomForestClassifier
    model = RandomForestClassifier(n_jobs=4, random_state=1)
    grid = GridSearchCV(model, param_grid, cv=10, scoring='accuracy', return_train_score=False)
    grid.fit(X, y)
    accuracy[feature]=list(grid.cv_results_["mean_test_score"])

accuracy
# Out:
# {}

# %%
# The output of following algorithm: 
# Model Hyper-Parameter Tuning Using GridSearch for Getting Optimized Value of n_estimators

rf_model_f1_test={'r_syn': [0.7829871405536469,
  0.8079669479047438,
  0.8121616965052084,
  0.8163089070834931,
  0.8156868226913007,
  0.8155657880897386,
  0.8168174906897735,
  0.8160890492889439,
  0.8166968138756453],
 'r_isa': [0.6191757394557095,
  0.6534362081426284,
  0.6584546959760401,
  0.6608880881155935,
  0.6615820444356472,
  0.6626576995418068,
  0.6638392344045112,
  0.6644348175708438,
  0.6663713448589391],
 'r_hypo': [0.4692204469409275,
  0.4997158183199241,
  0.5035527708760592,
  0.5062938794843082,
  0.5104377227642274,
  0.5101957060349473,
  0.5110044679030882,
  0.5101318927649376,
  0.5117000810055446],
 'r_lieu': [0.8182476414280948,
  0.8472020711877035,
  0.85188997087968,
  0.8539553637786296,
  0.8557853186531962,
  0.8560004347839381,
  0.8569393852545006,
  0.8572322570905009,
  0.8574918462994182],
 'r_agent_1': [0.6518958296093218,
  0.7004076796707291,
  0.7029580712018223,
  0.7044736033803771,
  0.7068093174036699,
  0.7122889956123422,
  0.711692511038783,
  0.713021865711632,
  0.7111114170583123],
 'r_agent': [0.3020056792453973,
  0.3014446213123851,
  0.3079342928887006,
  0.3139449153098319,
  0.30410219051593324,
  0.3064483804211511,
  0.3037424471422879,
  0.3069742113684945,
  0.3075473288686117]}

rf_model_accuracy_test={'r_syn': [0.8352416276944579,
  0.8518249744664839,
  0.8544858356179111,
  0.8574154706230178,
  0.856743535988819,
  0.856716658603451,
  0.8576304897059615,
  0.8571198193839703,
  0.8576036123205935],
 'r_isa': [0.9394183733806375,
  0.9442025479761329,
  0.9448476052249637,
  0.9450626243079073,
  0.9451432564640112,
  0.9453582755469548,
  0.9454657850884266,
  0.9456539267860022,
  0.9460302101811536],
 'r_hypo': [0.9400096758587324,
  0.9436918776541418,
  0.9441756705907649,
  0.944686340912756,
  0.9448744826103317,
  0.9448744826103317,
  0.9450626243079073,
  0.9450088695371714,
  0.9451432564640112],
 'r_lieu': [0.8817395043810138,
  0.8984303606945117,
  0.9010912218459388,
  0.9021663172606569,
  0.903214535290007,
  0.9032682900607429,
  0.9038327151534699,
  0.9041283663925174,
  0.904316508090093],
 'r_agent_1': [0.9310057517604687,
  0.9390958447562221,
  0.939687147234317,
  0.9398215341611568,
  0.9403053270977799,
  0.9412191582002902,
  0.9410578938880826,
  0.941380422512498,
  0.9410041391173467],
 'r_agent': [0.9736870397247755,
  0.9739020588077192,
  0.9739289361930872,
  0.9739826909638231,
  0.9739826909638231,
  0.9742245874321346,
  0.9741977100467667,
  0.9741708326613987,
  0.9741439552760307]}

# %%
import matplotlib.pyplot as plt

fig, axs = plt.subplots(3, 2,figsize=(12,12))

axs[0][0].plot(range(10,180,20), [rf_model_f1_test['r_syn'][i] for i in range(0,9,1)],color='blue',label='r_syn')
axs[0][1].plot(range(10,180,20), [rf_model_f1_test['r_isa'][i] for i in range(0,9,1)],color='red',label='r_isa')

axs[1][0].plot(range(10,180,20), [rf_model_f1_test['r_hypo'][i] for i in range(0,9,1)],color='orange',label='r_hypo')
axs[1][1].plot(range(10,180,20), [rf_model_f1_test['r_lieu'][i] for i in range(0,9,1)],color='green',label='r_lieu')

axs[2][0].plot(range(10,180,20), [rf_model_f1_test['r_agent'][i] for i in range(0,9,1)],color='black',label='r_agent')
axs[2][1].plot(range(10,180,20), [rf_model_f1_test['r_agent_1'][i] for i in range(0,9,1)],color='brown',label='r_agent_1')

from matplotlib.ticker import FormatStrFormatter
axs[0][0].yaxis.set_major_formatter(FormatStrFormatter("%.3f"))
axs[0][1].yaxis.set_major_formatter(FormatStrFormatter("%.3f"))
axs[1][0].yaxis.set_major_formatter(FormatStrFormatter("%.3f"))
axs[1][1].yaxis.set_major_formatter(FormatStrFormatter("%.3f"))
axs[2][0].yaxis.set_major_formatter(FormatStrFormatter("%.3f"))
axs[2][1].yaxis.set_major_formatter(FormatStrFormatter("%.3f"))


axs[0][0].set_ylabel('Cross-Validated F1')
axs[0][1].set_ylabel('Cross-Validated F1')
axs[1][0].set_ylabel('Cross-Validated F1')
axs[1][1].set_ylabel('Cross-Validated F1')
axs[2][0].set_ylabel('Cross-Validated F1')
axs[2][1].set_ylabel('Cross-Validated F1')

axs[0][0].set_xlabel('n_estimator')
axs[0][1].set_xlabel('n_estimator')
axs[1][0].set_xlabel('n_estimator')
axs[1][1].set_xlabel('n_estimator')
axs[2][0].set_xlabel('n_estimator')
axs[2][1].set_xlabel('n_estimator')

axs[0][0].legend()
axs[0][1].legend()

axs[1][0].legend()
axs[1][1].legend()

axs[2][0].legend()
axs[2][1].legend()

fig.savefig('n_estimator_optimization_1.jpg')

# %%
import matplotlib.pyplot as plt

fig, axs = plt.subplots(3, 2,figsize=(12,12))

axs[0][0].plot(range(10,180,20), [rf_model_accuracy_test['r_syn'][i] for i in range(0,9,1)],color='blue',label='r_syn')
axs[0][1].plot(range(10,180,20), [rf_model_accuracy_test['r_isa'][i] for i in range(0,9,1)],color='red',label='r_isa')

axs[1][0].plot(range(10,180,20), [rf_model_accuracy_test['r_hypo'][i] for i in range(0,9,1)],color='orange',label='r_hypo')
axs[1][1].plot(range(10,180,20), [rf_model_accuracy_test['r_lieu'][i] for i in range(0,9,1)],color='green',label='r_lieu')

axs[2][0].plot(range(10,180,20), [rf_model_accuracy_test['r_agent'][i] for i in range(0,9,1)],color='black',label='r_agent')
axs[2][1].plot(range(10,180,20), [rf_model_accuracy_test['r_agent_1'][i] for i in range(0,9,1)],color='brown',label='r_agent_1')

from matplotlib.ticker import FormatStrFormatter
axs[0][0].yaxis.set_major_formatter(FormatStrFormatter("%.3f"))
axs[0][1].yaxis.set_major_formatter(FormatStrFormatter("%.3f"))
axs[1][0].yaxis.set_major_formatter(FormatStrFormatter("%.3f"))
axs[1][1].yaxis.set_major_formatter(FormatStrFormatter("%.3f"))
axs[2][0].yaxis.set_major_formatter(FormatStrFormatter("%.3f"))
axs[2][1].yaxis.set_major_formatter(FormatStrFormatter("%.3f"))


axs[0][0].set_ylabel('Cross-Validated Accuracy')
axs[0][1].set_ylabel('Cross-Validated Accuracy')
axs[1][0].set_ylabel('Cross-Validated Accuracy')
axs[1][1].set_ylabel('Cross-Validated Accuracy')
axs[2][0].set_ylabel('Cross-Validated Accuracy')
axs[2][1].set_ylabel('Cross-Validated Accuracy')

axs[0][0].set_xlabel('n_estimator')
axs[0][1].set_xlabel('n_estimator')
axs[1][0].set_xlabel('n_estimator')
axs[1][1].set_xlabel('n_estimator')
axs[2][0].set_xlabel('n_estimator')
axs[2][1].set_xlabel('n_estimator')

axs[0][0].legend()
axs[0][1].legend()

axs[1][0].legend()
axs[1][1].legend()

axs[2][0].legend()
axs[2][1].legend()

fig.savefig('n_estimator_optimization_2.jpg')
